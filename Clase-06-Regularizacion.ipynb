# %% [markdown]
# ### Regularización
#
# Si el modelo es demasiado complejo ocurre el **sobreajuste** el modelo aprende sobre el ruido de nuestro modelo de entrenamiento y no es capaz de  generalizar bien.
# Para evitar el sobreajuste(overfitting) se puede recurrir a simplificar el modelo o a poner limitaciones sobre el mismo. Esto se conoce con el nombre de regularización.
# * Regularización Lasso o $L$: permite seleccionar los parámetros que más afectan al resultado. Se añade la función de coste:
# \\[
# Coste = {1 \over n} \sum_{i=0}^n{(Y-\hat{Y})^2}+\lambda \sum_j | \beta |
# \\]
# * Regularización Ridge o $L^2$: se evita que los parámetros crezcan demasiado. Se añade la función de coste:
# \\[
# Coste = {1 \over n} \sum_{i=0}^n{(Y-\hat{Y})^2}+\lambda \sum_j \beta^2
# \\]
# * Elástica: Una solución de compromiso entre las dos:
# \\[
# Coste = {1 \over n} \sum_{i=0}^n{(Y-\hat{Y})^2}+ \alpha \lambda \sum_j | \beta |+(1-\alpha)/2 \lambda \sum_j \beta^2
# \\]

# %% [markdown]
# ### Ejemplo regularización

# %% [markdown]
# Vamos a ver un ejemplo de regresión lineal con tres variables: x0, x1 y x2.
#
# La función que tratamos de modelizar es del tipo:
# \\[
# y=\beta_1+\beta_2·x_1+\beta_3·x_2+\beta_4·x_3
# \\]

# %%
#Definimos la función que queremos modelizar en función de beta
myfunction<-function(x_,beta){beta[1]+x_[,1]*beta[2]+x_[,2]*beta[3]+x_[,3]*beta[4]}

# %%
beta_real<-c(3,0.1,-5,4)

set.seed(123)
get_example_data_frame<-function(n=100){    
    x1<-runif(n,min=-10,max=10)
    x2<-rnorm(n,mean=7,sd=9)
    x3<-x1*rnorm(n,mean=3,sd=2)
 
    df<-data.frame(x1,x2,x3)
    df$y=myfunction(df,beta=beta_real)+rnorm(n,mean=0,sd=10)
    df
}
df<-get_example_data_frame()
head(df)
# Out:
#   x1        x2        x3         y
# 1 -4.248450  9.279867 -19.438686 -125.33495
# 2  5.766103  6.743079  26.167061   68.91070
# 3 -1.820462  6.614166  -6.670909  -60.37568
# 4  7.660348 19.317421   7.532013  -61.78805
# 5  8.809346  4.968061  24.323438   92.31947
# 6 -9.088870 20.648235 -22.169657 -190.71434

# %%
cor(df)
# Out:
#    x1          x2          x3         y
# x1  1.00000000 -0.02653768 0.85240646  0.7701336
# x2 -0.02653768  1.00000000 0.01350409 -0.4503744
# x3  0.85240646  0.01350409 1.00000000  0.8804553
# y   0.77013363 -0.45037439 0.88045529  1.0000000

# %%
library(GGally)
options(repr.plot.height=4,repr.plot.width=6,repr.plot.res = 200)
ggpairs(df)
# Out:
# Loading required package: ggplot2
#
# Registered S3 method overwritten by 'GGally':
#   method from
#   +.gg   ggplot2
# plot without title

# %%
model <- lm(y~x1+x2+x3,data=df)
summary(model)
# Out:
# Call:
# lm(formula = y ~ x1 + x2 + x3, data = df)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -21.560  -6.182  -0.610   7.208  21.655
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  4.37292    1.26409   3.459 0.000809 ***
# x1           0.12385    0.34041   0.364 0.716792
# x2          -5.01778    0.11686 -42.938  < 2e-16 ***
# x3           3.99738    0.09342  42.789  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 10.07 on 96 degrees of freedom
# Multiple R-squared:  0.9889,	Adjusted R-squared:  0.9886
# F-statistic:  2862 on 3 and 96 DF,  p-value: < 2.2e-16

# %%
confint(model)
# Out:
#             2.5 %      97.5 %
# (Intercept)  1.8637169  6.8821136
# x1          -0.5518635  0.7995614
# x2          -5.2497484 -4.7858148
# x3           3.8119412  4.1828175

# %%
library(pracma)
#Definimos una función de optimización que nos permite ver como evoluciona Beta

optim_beta<-function(mymodel,mse,maxiter=1e3,delta=0.0002,beta_0=c(0,0,0,0)){
    
    x_historico<-data.frame(beta1=rep(NA,maxiter),
                            beta2=rep(NA,maxiter),
                            beta3=rep(NA,maxiter),
                            beta4=rep(NA,maxiter),
                            mse=rep(NA,maxiter))
    x_historico[1,]<-c(beta_0,mse(beta_0))

    for (i in 2:maxiter){
        g <- grad(mse,beta_0)        
        beta_new <- beta_0 - g*delta
        beta_0 <- beta_new
        x_historico[i,]<-c(beta_0,mse=mse(beta_0))
    }
    x_historico<-na.omit(x_historico)
    nrow(x_historico)
    x_historico$step=1:nrow(x_historico)
    x_historico
}

# %%
#Definimos la métrica que queremos minimizar, en este caso el error cuadrático medio
mse<-function(beta){
    sum((df$y-myfunction(df[,c('x1','x2','x3')],beta))^2)/nrow(df)    
}
x_historico<-optim_beta(myfunction,mse,maxiter=1e4,delta=0.0005)

# %%
options(repr.plot.height=4,repr.plot.width=8)
g1<-ggplot(x_historico,aes(x=step))+geom_line(aes(y=beta1),color='red')+
    theme(axis.text.x = element_text(angle = 45))+geom_hline(yintercept=beta_real[1],color='black')
g2<-ggplot(x_historico,aes(x=step))+geom_line(aes(y=beta2),color='blue')+
    theme(axis.text.x = element_text(angle = 45))+geom_hline(yintercept=beta_real[2],color='black')
g3<-ggplot(x_historico,aes(x=step))+geom_line(aes(y=beta3),color='green')+
    theme(axis.text.x = element_text(angle = 45))+geom_hline(yintercept=beta_real[3],color='black')
g4<-ggplot(x_historico,aes(x=step))+geom_line(aes(y=beta4),color='orange')+
    theme(axis.text.x = element_text(angle = 45))+geom_hline(yintercept=beta_real[4],color='black')

library(egg)
grid.arrange(g1, g2, g3,g4, nrow = 1)
# Out:
# Error in ggplot(x_historico, aes(x = step)): could not find function "ggplot"
# Traceback:

# %%
model$coefficients
# Out:
# (Intercept)          x1          x2          x3
#    4.372915    0.123849   -5.017782    3.997379

# %% [markdown]
# #### Regularización Lasso
#
# Ahora vamos a aplicar una regularización L1 o de Lasso, añadamos el término:
#
# \\[
# Coste = {1 \over n} \sum_{i=0}^n{(Y-\hat{Y})^2}+\lambda \sum_j | \beta_j |
# \\]
#
# De los coeficientes $\beta_j$ no tenemos en cuenta la intersección. Notar que:
# * Cuando $\lambda \rightarrow 0$, entonces $\beta_{LASSO} \rightarrow \beta_{original mínimos cuadrados}$
# * Cuando $\lambda \rightarrow \infty$, entonces $\beta_{LASSO} \rightarrow 0$
#
# Tratamos de minimizar la suma de todos los demás coeficientes:

# %%
#lambda<-40
lambda<-2
loss_lasso<-function(beta){
    sum((df$y-myfunction(df[,-ncol(df)],beta))^2)/(2*nrow(df))+lambda*sum(abs(beta[-1]))
}
x_historico<-optim_beta(myfunction,loss_lasso,maxiter=1e4)

# %%
options(repr.plot.height=4,repr.plot.width=8)
library(ggplot2)

g1<-ggplot(x_historico,aes(x=step))+geom_line(aes(y=beta1),color='red')+
    theme(axis.text.x = element_text(angle = 45))+geom_hline(yintercept=beta_real[1],color='black')
g2<-ggplot(x_historico,aes(x=step))+geom_line(aes(y=beta2),color='blue')+
    theme(axis.text.x = element_text(angle = 45))+geom_hline(yintercept=beta_real[2],color='black')
g3<-ggplot(x_historico,aes(x=step))+geom_line(aes(y=beta3),color='green')+
    theme(axis.text.x = element_text(angle = 45))+geom_hline(yintercept=beta_real[3],color='black')
g4<-ggplot(x_historico,aes(x=step))+geom_line(aes(y=beta4),color='orange')+
    theme(axis.text.x = element_text(angle = 45))+geom_hline(yintercept=beta_real[4],color='black')

library(egg)
grid.arrange(g1, g2, g3,g4, nrow = 1)
# Out:
# plot without title

# %% [markdown]
# La regularización **Lasso** descarta los componentes que tienen menos certeza en el resultado final, es decir, los coeficientes con un pvalor más alto.
#
# En R existe el paquete [glmnet](https://web.stanford.edu/~hastie/glmnet/glmnet_alpha.html) que te permite apilcar regularización a modelos lineales

# %%
library(glmnet)
model<-glmnet(as.matrix(df[,c('x1','x2','x3')]),
              as.matrix(df[,'y']),
              lambda=2,alpha=1, standardize=F)
coefficients(model)
# Out:
# Loading required package: Matrix
#
#
# Attaching package: ‘Matrix’
#
#
# The following objects are masked from ‘package:pracma’:
#
#     expm, lu, tril, triu
#
#
# Loaded glmnet 4.1-4
# 4 x 1 sparse Matrix of class "dgCMatrix"
#                    s0
# (Intercept)  4.224618
# x1           .
# x2          -4.993921
# x3           4.021538

# %%
model
# Out:
# Call:  glmnet(x = as.matrix(df[, c("x1", "x2", "x3")]), y = as.matrix(df[,      "y"]), alpha = 1, lambda = 2, standardize = F)
#
#   Df  %Dev Lambda
# 1  2 98.89      2

# %% [markdown]
# Una vez que nos decantamos por una regularización Lasso ¿Cómo obtenemos el valor óptimo de $\lambda$ ?

# %%
fit<-glmnet(as.matrix(df[,c('x1','x2','x3')]),as.matrix(df[,'y']),alpha=1, standardize=F)
par(mfrow=c(1,3))
plot(fit,label=TRUE)
grid()
plot(fit,label=TRUE,xvar="lambda")
grid()
plot(fit,label=TRUE,xvar="dev")
grid()
#print(fit)
# Out:
# plot without title

# %%
#Calculamos los coeficientes para un valor dado de lambda
l<-exp(6)
coef(fit,s=l)
#Mostramos el valor de R^2 que se corresponde con la Fracción de la desviación típica explicada
caret::postResample(predict(fit,newx=as.matrix(df[,c('x1','x2','x3')]),s=l),df$y)
# Out:
# 4 x 1 sparse Matrix of class "dgCMatrix"
#                     s1
# (Intercept) -28.748311
# x1            .
# x2            .
# x3            3.052882
#       RMSE   Rsquared        MAE
# 48.5778924  0.7752015 40.1895646

# %% [markdown]
# Podemos ir probando con varios valores de $\lambda$ hasta encontrar con el *óptimo*.

# %%
lambda1 <- 2
lambda2 <- round(exp(6))
df_test<-get_example_data_frame(n=100)
df_test[,c("pred1","pred2")]<-predict(fit,newx=as.matrix(df_test[,c('x1','x2','x3')]),s=c(lambda1,lambda2))
head(df_test)
ggplot(df_test,aes(x=y))+
    geom_point(aes(y=pred1,color=paste0("lambda=",lambda1)))+
    geom_point(aes(y=pred2,color=paste0("lambda=",lambda2)))+
    geom_abline(slope=1,intercept=0,color="gray")+
    scale_colour_discrete(name = "Valor lambda" )+
    ylab("prediction")+xlab("real")
# Out:
#   x1        x2        x3           y            pred1       pred2
# 1  6.898671  6.337996  12.39149119   32.3059753   22.310340    9.094342
# 2 -4.797351 -3.517863  -4.85781066    0.4048667    1.900406  -43.583065
# 3 -9.537110  1.287266 -48.19645484 -197.5091619 -195.898978 -175.934358
# 4  7.247991  6.740426  32.63134319   85.3873655  101.571459   70.904549
# 5 -3.308241 13.036264   0.06065023  -54.3656883  -60.385715  -28.562645
# 6  2.635777 -7.854919   7.40575730   70.0538596   72.625699   -6.131523
# plot without title

# %% [markdown]
# Busca el mejor elemento utilizando validación cruzada (*cross-validation*):
#
# ![](img/cross-validation.png)

# %%
cvfit<-cv.glmnet(as.matrix(df[,c('x1','x2','x3')]),as.matrix(df[,'y']),nfolds=10,alpha=1, standarize=F)
plot(cvfit)
# Out:
# plot without title

# %% [markdown]
# El modelo que tiene un error cuadrático medio más bajo aparece en la variable *cvfit$lambda.min*
#
# El modelo que tiene un mayor valor de $\lambda$ cuya varianza del error está dentro de 1 *desviación típica* del *mínimo* aparece en la variable *cvfit$lambda.1se*.
#
# Al hacer cross-validation el MSE no será un valor único sino que tendremos *nfolds* diferentes. De todos estos MSE podemos calular la *media* y la *desviación típica*. El valor de *lambda.1se* viene a significar como el modelo más sencillo ($\lambda$ más alto) que no se diferencia considerablemente del *mínimo*.

# %%
options(repr.plot.height=2,repr.plot.width=5)
lamda_se<-1
qsd009<-function(x){    
    out<-dnorm(x)
    out[x> lamda_se  | x< -lamda_se  ]<-NA
    out
}
xdf<-data.frame(z=c(-4,4))
ggplot(xdf,aes(x=z))+stat_function(fun=dnorm)+
  stat_function(fun=qsd009, geom="area",fill="red")+
  geom_text(x=0,y=0.2,size=4,label=paste0(100*round(pnorm(lamda_se)-pnorm(-lamda_se),4),"%"))+  
  theme_linedraw()
options(repr.plot.height=7,repr.plot.width=7)
# Out:
# plot without title

# %%
cvfit$lambda.min
cvfit$lambda.1se
# Out:
# [1] 0.4511842
# [1] 2.642595

# %%
coef(cvfit, s = "lambda.1se")
# Out:
# 4 x 1 sparse Matrix of class "dgCMatrix"
#                    s1
# (Intercept)  2.324143
# x1           .
# x2          -4.710797
# x3           3.896718

# %% [markdown]
# Su R^2 estimado será:

# %%
cvfit$glmnet.fit$dev.ratio[which(cvfit$glmnet.fit$lambda == cvfit$lambda.1se)]
# Out:
# [1] 0.98732

# %% [markdown]
# En resumen, para hacer una predicción Lasso con glmnet haríamos:

# %%
cvfit<-cv.glmnet(as.matrix(df[,c('x1','x2','x3')]),as.matrix(df[,'y']),nfolds=10,alpha=1, standarize=F)

# %%
df_test<-get_example_data_frame(n=100)



df_test[,c("pred")]<-predict(cvfit,newx=as.matrix(df_test[,c('x1','x2','x3')]),s=cvfit$lambda.1se)
head(df_test)
caret::postResample(df_test$y,df_test$pred)
# Out:
#   x1         x2        x3          y          pred
# 1  1.9361383  3.972058   5.3340171   11.30191    4.534398
# 2  4.8417332 16.173018   8.0295401  -38.64590  -42.743196
# 3  9.0567426 -9.289640   9.5627518   79.14404   83.899767
# 4 -0.2075752 15.810312  -0.2039507  -62.10379  -73.203000
# 5 -8.3342531  3.095098 -45.7535663 -188.56495 -190.972616
# 6 -4.8014400 22.613531 -20.9445618 -192.01536 -186.498193
#       RMSE   Rsquared        MAE
# 11.0277353  0.9881218  9.1433518

# %% [markdown]
# #### Regularización Ridge
#
# Ahora vamos a aplicar una regularización L2 o Ridge, añadamos el término:
#
# \\[
# Coste = {1 \over n} \sum_{i=0}^n{(Y-\hat{Y})^2}+\lambda \sum_j \beta_j^2
# \\]
#
# De los coeficientes $\beta_j$ no tenemos en cuenta la intersección. Notar que:
# * Cuando $\lambda \rightarrow 0$, entonces $\beta_{RIDGE} \rightarrow \beta_{original mínimos cuadrados}$
# * Cuando $\lambda \rightarrow \infty$, entonces $\beta_{RIDGE} \rightarrow 0$
#
# Tratamos de minimizar la suma de todos los demás coeficientes:

# %%
lambda<-10
#lambda<-1000
loss_ridge<-function(beta){
    mean((df$y-myfunction(df[,c('x1','x2','x3')],beta))^2)+lambda*sum(beta[c(2,3,4)]^2)
}

x_historico<-optim_beta(myfunction,loss_ridge,maxiter=1e4,delta=0.0005 )

# %%
options(repr.plot.height=4,repr.plot.width=8)
library(ggplot2)

g1<-ggplot(x_historico,aes(x=step))+geom_line(aes(y=beta1),color='red')+
    theme(axis.text.x = element_text(angle = 45))+geom_hline(yintercept=beta_real[1],color='black')
g2<-ggplot(x_historico,aes(x=step))+geom_line(aes(y=beta2),color='blue')+
    theme(axis.text.x = element_text(angle = 45))+geom_hline(yintercept=beta_real[2],color='black')
g3<-ggplot(x_historico,aes(x=step))+geom_line(aes(y=beta3),color='green')+
    theme(axis.text.x = element_text(angle = 45))+geom_hline(yintercept=beta_real[3],color='black')
g4<-ggplot(x_historico,aes(x=step))+geom_line(aes(y=beta4),color='orange')+
    theme(axis.text.x = element_text(angle = 45))+geom_hline(yintercept=beta_real[4],color='black')

library(egg)
grid.arrange(g1, g2, g3,g4, nrow = 1)
# Out:
# Loading required package: gridExtra
# plot without title

# %% [markdown]
# La regularización **Ridge** acerca los coeficientes de las variables más correladas el uno hacia al otro.
#
# También podemos usar el paquete [glmnet](https://web.stanford.edu/~hastie/glmnet/glmnet_alpha.html), en este caso con $\alpha=0$ ya que utiliza la siguiente función de coste:
# \\[
# Coste = {1 \over n} \sum_{i=0}^n{(Y-\hat{Y})^2}+ \alpha \lambda \sum_j | \beta_j |+(1-\alpha)/2 \lambda \sum_j \beta_j^2
# \\]

# %%
library(glmnet)
model<-glmnet(as.matrix(df[,c('x1','x2','x3')]),as.matrix(df[,'y']),lambda=20,alpha=0, standardize=F)
coefficients(model)
# Out:
# Loading required package: Matrix
#
#
# Attaching package: ‘Matrix’
#
#
# The following objects are masked from ‘package:pracma’:
#
#     expm, lu, tril, triu
#
#
# Loaded glmnet 4.1-4
# 4 x 1 sparse Matrix of class "dgCMatrix"
#                    s0
# (Intercept)  4.271284
# x1           0.153316
# x2          -5.002668
# x3           3.988407

# %%
fit<-glmnet(as.matrix(df[,c('x1','x2','x3')]),as.matrix(df[,'y']),alpha=0, standardize=F)

par(mfrow=c(1,3))
plot(fit,label=TRUE)
plot(fit,label=TRUE,xvar="lambda")
plot(fit,label=TRUE,xvar="dev")
grid()
#print(fit)
# Out:
# plot without title

# %%
cvfit <- cv.glmnet(as.matrix(df[,c('x1','x2','x3')]),as.matrix(df[,'y']), nfolds=10, alpha=0, standardize=F)
plot(cvfit)
# Out:
# plot without title

# %% [markdown]
# El modelo que tiene un error cuadrático medio más bajo aparece en la variable *cvfit$lambda.min*
#
# El modelo que tiene un mayor valor de $\lambda$ cuya varianza del error está dentro de 1 *desviación típica* del *mínimo* aparece en la variable *cvfit$lambda.1se*.
#
# Al hacer cross-validation el MSE no será un valor único sino que tendremos *nfolds* diferentes. De todos estos MSE podemos calular la *media* y la *desviación típica*. El valor de *lambda.1se* viene a significar como el modelo más sencillo ($\lambda$ más alto) que no se diferencia considerablemente del *mínimo*.

# %%
cvfit$lambda.min
cvfit$lambda.1se
# Out:
# [1] 170.6533
# [1] 627.7278

# %%
coef(cvfit, s = "lambda.1se")
# Out:
# 4 x 1 sparse Matrix of class "dgCMatrix"
#                     s1
# (Intercept)  1.5549490
# x1           0.5137355
# x2          -4.5941169
# x3           3.8435075

# %%
cvfit$glmnet.fit$dev.ratio[which(cvfit$glmnet.fit$lambda == cvfit$lambda.1se)]
# Out:
# [1] 0.9871642

# %% [markdown]
# En resumen, para hacer una predicción Ridge con glmnet haríamos:

# %%
cvfit<-cv.glmnet(as.matrix(df[,c('x1','x2','x3')]),
                 as.matrix(df[,'y']),
                 nfolds=10,alpha=0, standardize=F)
cvfit$lambda.1se
# Out:
# [1] 521.1506

# %%
df_test<-get_example_data_frame(n=100)
df_test[,c("pred")]<-predict(cvfit,newx=as.matrix(df_test[,c('x1','x2','x3')]),s=cvfit$lambda.1se)
head(df_test)
caret::postResample(df_test$y,df_test$pred)
# Out:
#   x1         x2        x3         y         pred
# 1 -8.4489010 -1.735846 -12.045783 -20.59788 -40.468572
# 2  0.5867022 -8.264176   1.394628  66.46819  46.174806
# 3  8.9944799 12.965383  29.905473  56.72615  61.368116
# 4  7.1222611  6.253621  34.090987 100.76350 107.922844
# 5  0.9887229 -4.623462   2.309762  34.07416  32.933975
# 6  3.2990708  9.634870  10.106041 -18.25560  -2.300847
#      RMSE  Rsquared       MAE
# 11.422425  0.980373  9.261221

# %% [markdown]
# ### Prediciendo la dureza del hormigón con regularización
#
# Resumen: El hormigón es el material más importante en la ingeniería civil. La resistencia a la compresión del hormigón es una función altamente no lineal de la edad y ingredientes Estos ingredientes incluyen cemento, escoria de alto horno, cenizas volantes, agua, superplastificante, agregado grueso y agregado fino.
#
# Fuente:
# https://archive.ics.uci.edu/ml/datasets/Concrete+Compressive+Strength

# %%
concrete<-read.csv("data/Concrete_Data.csv",
                   col.names=c("cemento","escoria","cenizas","agua","plastificante","aggrueso","agfino","edad","resistencia"))
head(concrete)
# Out:
#   cemento escoria cenizas agua plastificante aggrueso agfino edad resistencia
# 1 540.0     0.0   0       162  2.5           1040.0   676.0   28  79.99
# 2 540.0     0.0   0       162  2.5           1055.0   676.0   28  61.89
# 3 332.5   142.5   0       228  0.0            932.0   594.0  270  40.27
# 4 332.5   142.5   0       228  0.0            932.0   594.0  365  41.05
# 5 198.6   132.4   0       192  0.0            978.4   825.5  360  44.30
# 6 266.0   114.0   0       228  0.0            932.0   670.0   90  47.03

# %%
options(repr.plot.height=5,repr.plot.width=8,repr.plot.res = 200)

GGally::ggpairs(concrete, 
       #lower = list(continuous = GGally::wrap("density", alpha = 0.8,size=0.2,color='blue'))
       lower = list(continuous = GGally::wrap("points", alpha = 0.3,size=0.1,color='blue'))
       )
# Out:
# Registered S3 method overwritten by 'GGally':
#   method from
#   +.gg   ggplot2
# plot without title

# %%
suppressPackageStartupMessages(library(tidyverse))
suppressPackageStartupMessages(library(glmnetUtils))

# %%
set.seed(12)

idx<-sample(1:nrow(concrete),nrow(concrete)*0.7)

concrete.train=concrete[idx,]
concrete.test=concrete[-idx,]

# %% [markdown]
# **Regresión lineal**

# %%
lm_model<-lm(resistencia~
           cemento*escoria*agua*plastificante*aggrueso*agfino*edad*cenizas,data = concrete.train)
summary(lm_model)
# Out:
# Call:
# lm(formula = resistencia ~ cemento * escoria * agua * plastificante *
#     aggrueso * agfino * edad * cenizas, data = concrete.train)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -23.1294  -3.2687   0.0126   3.3070  17.3214
#
# Coefficients: (15 not defined because of singularities)
#                                                                   Estimate
# (Intercept)                                                     -3.575e+04
# cemento                                                          4.842e+01
# escoria                                                          4.006e+02
# agua                                                             1.935e+02
# plastificante                                                   -7.536e+05
# aggrueso                                                         3.489e+01
# agfino                                                           4.427e+01
# edad                                                            -3.118e+01
# cenizas                                                          6.943e+03
# cemento:escoria                                                 -1.111e+00
# cemento:agua                                                    -2.635e-01
# escoria:agua                                                    -2.042e+00
# cemento:plastificante                                            2.830e+03
# escoria:plastificante                                            1.335e+03
# agua:plastificante                                               3.627e+03
# cemento:aggrueso                                                -4.431e-02
# escoria:aggrueso                                                -4.225e-01
# agua:aggrueso                                                   -1.891e-01
# plastificante:aggrueso                                           7.115e+02
# cemento:agfino                                                  -5.284e-02
# escoria:agfino                                                  -5.085e-01
# agua:agfino                                                     -2.382e-01
# plastificante:agfino                                             7.703e+02
# aggrueso:agfino                                                 -4.279e-02
# cemento:edad                                                     5.039e-01
# escoria:edad                                                    -1.038e+01
# agua:edad                                                        2.475e-02
# plastificante:edad                                               2.709e+04
# aggrueso:edad                                                    4.074e-02
# agfino:edad                                                     -1.736e-02
# cemento:cenizas                                                 -2.345e+01
# escoria:cenizas                                                 -1.726e+02
# agua:cenizas                                                    -6.532e+00
# plastificante:cenizas                                            1.045e+03
# aggrueso:cenizas                                                -3.907e+00
# agfino:cenizas                                                  -5.982e+00
# edad:cenizas                                                    -2.436e+02
# cemento:escoria:agua                                             5.400e-03
# cemento:escoria:plastificante                                   -6.730e+00
# cemento:agua:plastificante                                      -1.551e+01
# escoria:agua:plastificante                                      -6.030e+00
# cemento:escoria:aggrueso                                         1.204e-03
# cemento:agua:aggrueso                                            2.433e-04
# escoria:agua:aggrueso                                            2.151e-03
# cemento:plastificante:aggrueso                                  -2.857e+00
# escoria:plastificante:aggrueso                                  -1.041e-01
# agua:plastificante:aggrueso                                     -3.493e+00
# cemento:escoria:agfino                                           1.310e-03
# cemento:agua:agfino                                              2.861e-04
# escoria:agua:agfino                                              2.576e-03
# cemento:plastificante:agfino                                    -2.911e+00
# escoria:plastificante:agfino                                     4.255e-02
# agua:plastificante:agfino                                       -3.532e+00
# cemento:aggrueso:agfino                                          4.652e-05
# escoria:aggrueso:agfino                                          5.358e-04
# agua:aggrueso:agfino                                             2.307e-04
# plastificante:aggrueso:agfino                                   -7.219e-01
# cemento:escoria:edad                                             4.030e-02
# cemento:agua:edad                                               -2.338e-03
# escoria:agua:edad                                                5.221e-02
# cemento:plastificante:edad                                      -1.014e+02
# escoria:plastificante:edad                                      -4.863e+01
# agua:plastificante:edad                                         -1.305e+02
# cemento:aggrueso:edad                                           -5.681e-04
# escoria:aggrueso:edad                                            1.116e-02
# agua:aggrueso:edad                                              -7.668e-05
# plastificante:aggrueso:edad                                     -2.558e+01
# cemento:agfino:edad                                             -6.403e-04
# escoria:agfino:edad                                              1.361e-02
# agua:agfino:edad                                                 2.325e-04
# plastificante:agfino:edad                                       -2.771e+01
# aggrueso:agfino:edad                                            -6.335e-06
# cemento:escoria:cenizas                                          4.161e-01
# cemento:agua:cenizas                                             7.746e-02
# escoria:agua:cenizas                                             8.191e-01
# cemento:plastificante:cenizas                                   -1.013e+00
# escoria:plastificante:cenizas                                    9.388e+00
# agua:plastificante:cenizas                                      -4.009e+00
# cemento:aggrueso:cenizas                                         1.177e-02
# escoria:aggrueso:cenizas                                         8.145e-02
# agua:aggrueso:cenizas                                           -8.656e-03
# plastificante:aggrueso:cenizas                                  -1.128e+00
# cemento:agfino:cenizas                                           1.998e-02
# escoria:agfino:cenizas                                           7.487e-02
# agua:agfino:cenizas                                             -2.855e-03
# plastificante:agfino:cenizas                                    -3.052e-01
# aggrueso:agfino:cenizas                                          2.543e-03
# cemento:edad:cenizas                                             8.470e-01
# escoria:edad:cenizas                                             6.108e+00
# agua:edad:cenizas                                                2.135e-01
# plastificante:edad:cenizas                                      -3.823e+01
# aggrueso:edad:cenizas                                            1.358e-01
# agfino:edad:cenizas                                              2.101e-01
# cemento:escoria:agua:plastificante                               3.970e-02
# cemento:escoria:agua:aggrueso                                   -5.852e-06
# cemento:escoria:plastificante:aggrueso                           4.282e-03
# cemento:agua:plastificante:aggrueso                              1.613e-02
# escoria:agua:plastificante:aggrueso                              5.684e-04
# cemento:escoria:agua:agfino                                     -6.242e-06
# cemento:escoria:plastificante:agfino                             2.107e-03
# cemento:agua:plastificante:agfino                                1.563e-02
# escoria:agua:plastificante:agfino                               -2.507e-03
# cemento:escoria:aggrueso:agfino                                 -1.426e-06
# cemento:agua:aggrueso:agfino                                    -2.546e-07
# escoria:agua:aggrueso:agfino                                    -2.711e-06
# cemento:plastificante:aggrueso:agfino                            2.954e-03
# escoria:plastificante:aggrueso:agfino                           -1.581e-03
# agua:plastificante:aggrueso:agfino                               3.388e-03
# cemento:escoria:agua:edad                                       -2.009e-04
# cemento:escoria:plastificante:edad                               2.420e-01
# cemento:agua:plastificante:edad                                  5.560e-01
# escoria:agua:plastificante:edad                                  2.206e-01
# cemento:escoria:aggrueso:edad                                   -4.365e-05
# cemento:agua:aggrueso:edad                                       2.678e-06
# escoria:agua:aggrueso:edad                                      -5.609e-05
# cemento:plastificante:aggrueso:edad                              1.024e-01
# escoria:plastificante:aggrueso:edad                              4.689e-03
# agua:plastificante:aggrueso:edad                                 1.257e-01
# cemento:escoria:agfino:edad                                     -5.036e-05
# cemento:agua:agfino:edad                                         3.057e-06
# escoria:agua:agfino:edad                                        -6.826e-05
# cemento:plastificante:agfino:edad                                1.044e-01
# escoria:plastificante:agfino:edad                               -4.145e-04
# agua:plastificante:agfino:edad                                   1.272e-01
# cemento:aggrueso:agfino:edad                                     7.661e-07
# escoria:aggrueso:agfino:edad                                    -1.460e-05
# agua:aggrueso:agfino:edad                                       -1.081e-07
# plastificante:aggrueso:agfino:edad                               2.598e-02
# cemento:escoria:agua:cenizas                                    -1.288e-03
# cemento:escoria:plastificante:cenizas                           -4.105e-02
# cemento:agua:plastificante:cenizas                               5.671e-03
# escoria:agua:plastificante:cenizas                              -2.922e-02
# cemento:escoria:aggrueso:cenizas                                -3.126e-04
# cemento:agua:aggrueso:cenizas                                   -1.959e-05
# escoria:agua:aggrueso:cenizas                                   -3.879e-04
# cemento:plastificante:aggrueso:cenizas                           3.046e-03
# escoria:plastificante:aggrueso:cenizas                          -5.411e-03
# agua:plastificante:aggrueso:cenizas                              5.209e-03
# cemento:escoria:agfino:cenizas                                  -1.180e-05
# cemento:agua:agfino:cenizas                                     -6.071e-05
# escoria:agua:agfino:cenizas                                     -4.024e-04
# cemento:plastificante:agfino:cenizas                            -2.464e-03
# escoria:plastificante:agfino:cenizas                            -7.308e-04
# agua:plastificante:agfino:cenizas                               -1.549e-03
# cemento:aggrueso:agfino:cenizas                                 -6.880e-06
# escoria:aggrueso:agfino:cenizas                                  1.210e-05
# agua:aggrueso:agfino:cenizas                                     2.005e-05
# plastificante:aggrueso:agfino:cenizas                            3.935e-04
# cemento:escoria:edad:cenizas                                    -1.467e-02
# cemento:agua:edad:cenizas                                       -2.835e-03
# escoria:agua:edad:cenizas                                       -2.897e-02
# cemento:plastificante:edad:cenizas                               3.820e-02
# escoria:plastificante:edad:cenizas                              -3.354e-01
# agua:plastificante:edad:cenizas                                  1.475e-01
# cemento:aggrueso:edad:cenizas                                   -4.317e-04
# escoria:aggrueso:edad:cenizas                                   -2.830e-03
# agua:aggrueso:edad:cenizas                                       3.259e-04
# plastificante:aggrueso:edad:cenizas                              4.115e-02
# cemento:agfino:edad:cenizas                                     -7.332e-04
# escoria:agfino:edad:cenizas                                     -2.595e-03
# agua:agfino:edad:cenizas                                         1.164e-04
# plastificante:agfino:edad:cenizas                                1.181e-02
# aggrueso:agfino:edad:cenizas                                    -8.796e-05
# cemento:escoria:agua:plastificante:aggrueso                     -3.091e-05
# cemento:escoria:agua:plastificante:agfino                       -1.133e-05
# cemento:escoria:agua:aggrueso:agfino                             6.798e-09
# cemento:escoria:plastificante:aggrueso:agfino                    1.034e-06
# cemento:agua:plastificante:aggrueso:agfino                      -1.645e-05
# escoria:agua:plastificante:aggrueso:agfino                       9.354e-06
# cemento:escoria:agua:plastificante:edad                         -1.426e-03
# cemento:escoria:agua:aggrueso:edad                               2.173e-07
# cemento:escoria:plastificante:aggrueso:edad                     -1.545e-04
# cemento:agua:plastificante:aggrueso:edad                        -5.780e-04
# escoria:agua:plastificante:aggrueso:edad                        -2.560e-05
# cemento:escoria:agua:agfino:edad                                 2.494e-07
# cemento:escoria:plastificante:agfino:edad                       -7.687e-05
# cemento:agua:plastificante:agfino:edad                          -5.602e-04
# escoria:agua:plastificante:agfino:edad                           8.354e-05
# cemento:escoria:aggrueso:agfino:edad                             5.463e-08
# cemento:agua:aggrueso:agfino:edad                               -3.712e-09
# escoria:agua:aggrueso:agfino:edad                                7.316e-08
# cemento:plastificante:aggrueso:agfino:edad                      -1.059e-04
# escoria:plastificante:aggrueso:agfino:edad                       5.534e-05
# agua:plastificante:aggrueso:agfino:edad                         -1.220e-04
# cemento:escoria:agua:plastificante:cenizas                       9.606e-05
# cemento:escoria:agua:aggrueso:cenizas                            1.175e-06
# cemento:escoria:plastificante:aggrueso:cenizas                   1.761e-05
# cemento:agua:plastificante:aggrueso:cenizas                     -2.061e-05
# escoria:agua:plastificante:aggrueso:cenizas                      9.372e-06
# cemento:escoria:agua:agfino:cenizas                             -5.464e-07
# cemento:escoria:plastificante:agfino:cenizas                     8.391e-06
# cemento:agua:plastificante:agfino:cenizas                        1.826e-05
# escoria:agua:plastificante:agfino:cenizas                        1.198e-07
# cemento:escoria:aggrueso:agfino:cenizas                          1.479e-08
# cemento:agua:aggrueso:agfino:cenizas                            -3.954e-09
# escoria:agua:aggrueso:agfino:cenizas                             1.706e-08
# cemento:plastificante:aggrueso:agfino:cenizas                    4.233e-08
# escoria:plastificante:aggrueso:agfino:cenizas                    6.331e-08
# agua:plastificante:aggrueso:agfino:cenizas                       1.041e-07
# cemento:escoria:agua:edad:cenizas                                4.497e-05
# cemento:escoria:plastificante:edad:cenizas                       1.481e-03
# cemento:agua:plastificante:edad:cenizas                         -2.106e-04
# escoria:agua:plastificante:edad:cenizas                          1.044e-03
# cemento:escoria:aggrueso:edad:cenizas                            1.081e-05
# cemento:agua:aggrueso:edad:cenizas                               7.779e-07
# escoria:agua:aggrueso:edad:cenizas                               1.344e-05
# cemento:plastificante:aggrueso:edad:cenizas                     -1.106e-04
# escoria:plastificante:aggrueso:edad:cenizas                      1.924e-04
# agua:plastificante:aggrueso:edad:cenizas                        -1.901e-04
# cemento:escoria:agfino:edad:cenizas                              1.323e-07
# cemento:agua:agfino:edad:cenizas                                 2.296e-06
# escoria:agua:agfino:edad:cenizas                                 1.395e-05
# cemento:plastificante:agfino:edad:cenizas                        8.623e-05
# escoria:plastificante:agfino:edad:cenizas                        2.559e-05
# agua:plastificante:agfino:edad:cenizas                           5.116e-05
# cemento:aggrueso:agfino:edad:cenizas                             2.674e-07
# escoria:aggrueso:agfino:edad:cenizas                            -5.471e-07
# agua:aggrueso:agfino:edad:cenizas                               -7.264e-07
# plastificante:aggrueso:agfino:edad:cenizas                      -1.488e-05
# cemento:escoria:agua:plastificante:aggrueso:agfino              -2.223e-10
# cemento:escoria:agua:plastificante:aggrueso:edad                 1.112e-06
# cemento:escoria:agua:plastificante:agfino:edad                   4.126e-07
# cemento:escoria:agua:aggrueso:agfino:edad                       -2.704e-10
# cemento:escoria:plastificante:aggrueso:agfino:edad              -3.532e-08
# cemento:agua:plastificante:aggrueso:agfino:edad                  5.897e-07
# escoria:agua:plastificante:aggrueso:agfino:edad                 -3.280e-07
# cemento:escoria:agua:plastificante:aggrueso:cenizas              1.002e-09
# cemento:escoria:agua:plastificante:agfino:cenizas                1.781e-09
# cemento:escoria:agua:aggrueso:agfino:cenizas                    -8.004e-11
# cemento:escoria:plastificante:aggrueso:agfino:cenizas            3.342e-11
# cemento:agua:plastificante:aggrueso:agfino:cenizas              -1.182e-10
# escoria:agua:plastificante:aggrueso:agfino:cenizas              -3.883e-10
# cemento:escoria:agua:plastificante:edad:cenizas                 -3.509e-06
# cemento:escoria:agua:aggrueso:edad:cenizas                      -4.008e-08
# cemento:escoria:plastificante:aggrueso:edad:cenizas             -6.363e-07
# cemento:agua:plastificante:aggrueso:edad:cenizas                 7.429e-07
# escoria:agua:plastificante:aggrueso:edad:cenizas                -3.296e-07
# cemento:escoria:agua:agfino:edad:cenizas                         2.109e-08
# cemento:escoria:plastificante:agfino:edad:cenizas               -3.134e-07
# cemento:agua:plastificante:agfino:edad:cenizas                  -6.464e-07
# escoria:agua:plastificante:agfino:edad:cenizas                          NA
# cemento:escoria:aggrueso:agfino:edad:cenizas                            NA
# cemento:agua:aggrueso:agfino:edad:cenizas                               NA
# escoria:agua:aggrueso:agfino:edad:cenizas                               NA
# cemento:plastificante:aggrueso:agfino:edad:cenizas                      NA
# escoria:plastificante:aggrueso:agfino:edad:cenizas                      NA
# agua:plastificante:aggrueso:agfino:edad:cenizas                         NA
# cemento:escoria:agua:plastificante:aggrueso:agfino:edad                 NA
# cemento:escoria:agua:plastificante:aggrueso:agfino:cenizas       1.872e-13
# cemento:escoria:agua:plastificante:aggrueso:edad:cenizas                NA
# cemento:escoria:agua:plastificante:agfino:edad:cenizas                  NA
# cemento:escoria:agua:aggrueso:agfino:edad:cenizas                       NA
# cemento:escoria:plastificante:aggrueso:agfino:edad:cenizas              NA
# cemento:agua:plastificante:aggrueso:agfino:edad:cenizas                 NA
# escoria:agua:plastificante:aggrueso:agfino:edad:cenizas                 NA
# cemento:escoria:agua:plastificante:aggrueso:agfino:edad:cenizas         NA
#                                                                 Std. Error
# (Intercept)                                                      1.500e+04
# cemento                                                          2.893e+01
# escoria                                                          2.211e+02
# agua                                                             7.900e+01
# plastificante                                                    8.014e+05
# aggrueso                                                         1.547e+01
# agfino                                                           1.907e+01
# edad                                                             3.350e+02
# cenizas                                                          8.019e+03
# cemento:escoria                                                  1.128e+00
# cemento:agua                                                     1.523e-01
# escoria:agua                                                     1.137e+00
# cemento:plastificante                                            3.116e+03
# escoria:plastificante                                            1.431e+03
# agua:plastificante                                               3.695e+03
# cemento:aggrueso                                                 2.963e-02
# escoria:aggrueso                                                 2.369e-01
# agua:aggrueso                                                    8.169e-02
# plastificante:aggrueso                                           7.833e+02
# cemento:agfino                                                   3.758e-02
# escoria:agfino                                                   3.020e-01
# agua:agfino                                                      1.007e-01
# plastificante:agfino                                             8.107e+02
# aggrueso:agfino                                                  1.957e-02
# cemento:edad                                                     6.795e-01
# escoria:edad                                                     7.572e+00
# agua:edad                                                        1.736e+00
# plastificante:edad                                               2.862e+04
# aggrueso:edad                                                    3.511e-01
# agfino:edad                                                      4.524e-01
# cemento:cenizas                                                  2.790e+01
# escoria:cenizas                                                  2.543e+02
# agua:cenizas                                                     2.660e+01
# plastificante:cenizas                                            1.100e+03
# aggrueso:cenizas                                                 5.266e+00
# agfino:cenizas                                                   7.054e+00
# edad:cenizas                                                     2.865e+02
# cemento:escoria:agua                                             5.792e-03
# cemento:escoria:plastificante                                    7.385e+00
# cemento:agua:plastificante                                       1.697e+01
# escoria:agua:plastificante                                       6.968e+00
# cemento:escoria:aggrueso                                         1.210e-03
# cemento:agua:aggrueso                                            1.566e-04
# escoria:agua:aggrueso                                            1.219e-03
# cemento:plastificante:aggrueso                                   3.246e+00
# escoria:plastificante:aggrueso                                   3.979e-01
# agua:plastificante:aggrueso                                      3.735e+00
# cemento:escoria:agfino                                           1.572e-03
# cemento:agua:agfino                                              1.994e-04
# escoria:agua:agfino                                              1.556e-03
# cemento:plastificante:agfino                                     3.167e+00
# escoria:plastificante:agfino                                     6.653e-01
# agua:plastificante:agfino                                        3.542e+00
# cemento:aggrueso:agfino                                          3.857e-05
# escoria:aggrueso:agfino                                          3.238e-04
# agua:aggrueso:agfino                                             1.036e-04
# plastificante:aggrueso:agfino                                    7.956e-01
# cemento:escoria:edad                                             4.015e-02
# cemento:agua:edad                                                3.550e-03
# escoria:agua:edad                                                3.879e-02
# cemento:plastificante:edad                                       1.113e+02
# escoria:plastificante:edad                                       5.111e+01
# agua:plastificante:edad                                          1.320e+02
# cemento:aggrueso:edad                                            7.135e-04
# escoria:aggrueso:edad                                            8.130e-03
# agua:aggrueso:edad                                               1.820e-03
# plastificante:aggrueso:edad                                      2.797e+01
# cemento:agfino:edad                                              9.709e-04
# escoria:agfino:edad                                              1.041e-02
# agua:agfino:edad                                                 2.358e-03
# plastificante:agfino:edad                                        2.895e+01
# aggrueso:agfino:edad                                             4.728e-04
# cemento:escoria:cenizas                                          6.643e-01
# cemento:agua:cenizas                                             1.031e-01
# escoria:agua:cenizas                                             1.077e+00
# cemento:plastificante:cenizas                                    1.212e+00
# escoria:plastificante:cenizas                                    9.987e+00
# agua:plastificante:cenizas                                       3.552e+00
# cemento:aggrueso:cenizas                                         1.457e-02
# escoria:aggrueso:cenizas                                         2.347e-01
# agua:aggrueso:cenizas                                            3.243e-02
# plastificante:aggrueso:cenizas                                   1.479e+00
# cemento:agfino:cenizas                                           2.252e-02
# escoria:agfino:cenizas                                           9.557e-02
# agua:agfino:cenizas                                              3.527e-02
# plastificante:agfino:cenizas                                     2.785e-01
# aggrueso:agfino:cenizas                                          4.851e-03
# cemento:edad:cenizas                                             9.970e-01
# escoria:edad:cenizas                                             9.076e+00
# agua:edad:cenizas                                                9.495e-01
# plastificante:edad:cenizas                                       3.924e+01
# aggrueso:edad:cenizas                                            1.881e-01
# agfino:edad:cenizas                                              2.520e-01
# cemento:escoria:agua:plastificante                               4.573e-02
# cemento:escoria:agua:aggrueso                                    6.215e-06
# cemento:escoria:plastificante:aggrueso                           4.786e-03
# cemento:agua:plastificante:aggrueso                              1.841e-02
# escoria:agua:plastificante:aggrueso                              2.741e-03
# cemento:escoria:agua:agfino                                      8.088e-06
# cemento:escoria:plastificante:agfino                             1.857e-03
# cemento:agua:plastificante:agfino                                1.684e-02
# escoria:agua:plastificante:agfino                                5.643e-03
# cemento:escoria:aggrueso:agfino                                  1.687e-06
# cemento:agua:aggrueso:agfino                                     2.053e-07
# escoria:agua:aggrueso:agfino                                     1.668e-06
# cemento:plastificante:aggrueso:agfino                            3.343e-03
# escoria:plastificante:aggrueso:agfino                            2.164e-03
# agua:plastificante:aggrueso:agfino                               3.626e-03
# cemento:escoria:agua:edad                                        2.058e-04
# cemento:escoria:plastificante:edad                               2.637e-01
# cemento:agua:plastificante:edad                                  6.061e-01
# escoria:agua:plastificante:edad                                  2.489e-01
# cemento:escoria:aggrueso:edad                                    4.309e-05
# cemento:agua:aggrueso:edad                                       3.732e-06
# escoria:agua:aggrueso:edad                                       4.165e-05
# cemento:plastificante:aggrueso:edad                              1.159e-01
# escoria:plastificante:aggrueso:edad                              1.421e-02
# agua:plastificante:aggrueso:edad                                 1.334e-01
# cemento:escoria:agfino:edad                                      5.603e-05
# cemento:agua:agfino:edad                                         5.120e-06
# escoria:agua:agfino:edad                                         5.347e-05
# cemento:plastificante:agfino:edad                                1.131e-01
# escoria:plastificante:agfino:edad                                2.376e-02
# agua:plastificante:agfino:edad                                   1.265e-01
# cemento:aggrueso:agfino:edad                                     1.023e-06
# escoria:aggrueso:agfino:edad                                     1.118e-05
# agua:aggrueso:agfino:edad                                        2.465e-06
# plastificante:aggrueso:agfino:edad                               2.841e-02
# cemento:escoria:agua:cenizas                                     2.755e-03
# cemento:escoria:plastificante:cenizas                            4.945e-02
# cemento:agua:plastificante:cenizas                               7.813e-03
# escoria:agua:plastificante:cenizas                               2.599e-02
# cemento:escoria:aggrueso:cenizas                                 6.383e-04
# cemento:agua:aggrueso:cenizas                                    3.636e-05
# escoria:agua:aggrueso:cenizas                                    7.926e-04
# cemento:plastificante:aggrueso:cenizas                           3.702e-03
# escoria:plastificante:aggrueso:cenizas                           6.557e-03
# agua:plastificante:aggrueso:cenizas                              6.291e-03
# cemento:escoria:agfino:cenizas                                   5.160e-04
# cemento:agua:agfino:cenizas                                      7.592e-05
# escoria:agua:agfino:cenizas                                      8.738e-04
# cemento:plastificante:agfino:cenizas                             4.224e-03
# escoria:plastificante:agfino:cenizas                             1.884e-03
# agua:plastificante:agfino:cenizas                                5.039e-03
# cemento:aggrueso:agfino:cenizas                                  8.044e-06
# escoria:aggrueso:agfino:cenizas                                  1.073e-04
# agua:aggrueso:agfino:cenizas                                     4.774e-05
# plastificante:aggrueso:agfino:cenizas                            6.917e-04
# cemento:escoria:edad:cenizas                                     2.369e-02
# cemento:agua:edad:cenizas                                        3.685e-03
# escoria:agua:edad:cenizas                                        3.844e-02
# cemento:plastificante:edad:cenizas                               4.306e-02
# escoria:plastificante:edad:cenizas                               3.557e-01
# agua:plastificante:edad:cenizas                                  1.263e-01
# cemento:aggrueso:edad:cenizas                                    5.207e-04
# escoria:aggrueso:edad:cenizas                                    8.378e-03
# agua:aggrueso:edad:cenizas                                       1.157e-03
# plastificante:aggrueso:edad:cenizas                              5.277e-02
# cemento:agfino:edad:cenizas                                      8.048e-04
# escoria:agfino:edad:cenizas                                      3.395e-03
# agua:agfino:edad:cenizas                                         1.258e-03
# plastificante:agfino:edad:cenizas                                9.767e-03
# aggrueso:agfino:edad:cenizas                                     1.732e-04
# cemento:escoria:agua:plastificante:aggrueso                      3.790e-05
# cemento:escoria:agua:plastificante:agfino                        1.099e-05
# cemento:escoria:agua:aggrueso:agfino                             8.682e-09
# cemento:escoria:plastificante:aggrueso:agfino                    2.437e-06
# cemento:agua:plastificante:aggrueso:agfino                       1.871e-05
# escoria:agua:plastificante:aggrueso:agfino                       1.184e-05
# cemento:escoria:agua:plastificante:edad                          1.633e-03
# cemento:escoria:agua:aggrueso:edad                               2.209e-07
# cemento:escoria:plastificante:aggrueso:edad                      1.709e-04
# cemento:agua:plastificante:aggrueso:edad                         6.575e-04
# escoria:agua:plastificante:aggrueso:edad                         9.790e-05
# cemento:escoria:agua:agfino:edad                                 2.878e-07
# cemento:escoria:plastificante:agfino:edad                        6.629e-05
# cemento:agua:plastificante:agfino:edad                           6.014e-04
# escoria:agua:plastificante:agfino:edad                           2.015e-04
# cemento:escoria:aggrueso:agfino:edad                             6.015e-08
# cemento:agua:aggrueso:agfino:edad                                5.397e-09
# escoria:agua:aggrueso:agfino:edad                                5.743e-08
# cemento:plastificante:aggrueso:agfino:edad                       1.194e-04
# escoria:plastificante:aggrueso:agfino:edad                       7.728e-05
# agua:plastificante:aggrueso:agfino:edad                          1.295e-04
# cemento:escoria:agua:plastificante:cenizas                       1.190e-04
# cemento:escoria:agua:aggrueso:cenizas                            2.721e-06
# cemento:escoria:plastificante:aggrueso:cenizas                   2.578e-05
# cemento:agua:plastificante:aggrueso:cenizas                      2.493e-05
# escoria:agua:plastificante:aggrueso:cenizas                      9.666e-06
# cemento:escoria:agua:agfino:cenizas                              3.295e-06
# cemento:escoria:plastificante:agfino:cenizas                     1.011e-05
# cemento:agua:plastificante:agfino:cenizas                        3.135e-05
# escoria:agua:plastificante:agfino:cenizas                        4.311e-06
# cemento:escoria:aggrueso:agfino:cenizas                          4.491e-08
# cemento:agua:aggrueso:agfino:cenizas                             4.374e-09
# escoria:agua:aggrueso:agfino:cenizas                             4.022e-08
# cemento:plastificante:aggrueso:agfino:cenizas                    8.941e-08
# escoria:plastificante:aggrueso:agfino:cenizas                    8.806e-07
# agua:plastificante:aggrueso:agfino:cenizas                       1.747e-07
# cemento:escoria:agua:edad:cenizas                                9.818e-05
# cemento:escoria:plastificante:edad:cenizas                       1.760e-03
# cemento:agua:plastificante:edad:cenizas                          2.779e-04
# escoria:agua:plastificante:edad:cenizas                          9.188e-04
# cemento:escoria:aggrueso:edad:cenizas                            2.276e-05
# cemento:agua:aggrueso:edad:cenizas                               1.297e-06
# escoria:agua:aggrueso:edad:cenizas                               2.828e-05
# cemento:plastificante:aggrueso:edad:cenizas                      1.321e-04
# escoria:plastificante:aggrueso:edad:cenizas                      2.326e-04
# agua:plastificante:aggrueso:edad:cenizas                         2.244e-04
# cemento:escoria:agfino:edad:cenizas                              1.837e-05
# cemento:agua:agfino:edad:cenizas                                 2.712e-06
# escoria:agua:agfino:edad:cenizas                                 3.117e-05
# cemento:plastificante:agfino:edad:cenizas                        1.509e-04
# escoria:plastificante:agfino:edad:cenizas                        6.056e-05
# agua:plastificante:agfino:edad:cenizas                           1.798e-04
# cemento:aggrueso:agfino:edad:cenizas                             2.865e-07
# escoria:aggrueso:agfino:edad:cenizas                             3.817e-06
# agua:aggrueso:agfino:edad:cenizas                                1.704e-06
# plastificante:aggrueso:agfino:edad:cenizas                       2.465e-05
# cemento:escoria:agua:plastificante:aggrueso:agfino               2.420e-10
# cemento:escoria:agua:plastificante:aggrueso:edad                 1.353e-06
# cemento:escoria:agua:plastificante:agfino:edad                   3.925e-07
# cemento:escoria:agua:aggrueso:agfino:edad                        3.091e-10
# cemento:escoria:plastificante:aggrueso:agfino:edad               8.701e-08
# cemento:agua:plastificante:aggrueso:agfino:edad                  6.681e-07
# escoria:agua:plastificante:aggrueso:agfino:edad                  4.229e-07
# cemento:escoria:agua:plastificante:aggrueso:cenizas              2.131e-08
# cemento:escoria:agua:plastificante:agfino:cenizas                2.586e-08
# cemento:escoria:agua:aggrueso:agfino:cenizas                     2.356e-10
# cemento:escoria:plastificante:aggrueso:agfino:cenizas            5.277e-09
# cemento:agua:plastificante:aggrueso:agfino:cenizas               4.865e-10
# escoria:agua:plastificante:aggrueso:agfino:cenizas               4.690e-09
# cemento:escoria:agua:plastificante:edad:cenizas                  4.186e-06
# cemento:escoria:agua:aggrueso:edad:cenizas                       9.694e-08
# cemento:escoria:plastificante:aggrueso:edad:cenizas              9.079e-07
# cemento:agua:plastificante:aggrueso:edad:cenizas                 8.897e-07
# escoria:agua:plastificante:aggrueso:edad:cenizas                 3.173e-07
# cemento:escoria:agua:agfino:edad:cenizas                         1.175e-07
# cemento:escoria:plastificante:agfino:edad:cenizas                3.142e-07
# cemento:agua:plastificante:agfino:edad:cenizas                   1.120e-06
# escoria:agua:plastificante:agfino:edad:cenizas                          NA
# cemento:escoria:aggrueso:agfino:edad:cenizas                            NA
# cemento:agua:aggrueso:agfino:edad:cenizas                               NA
# escoria:agua:aggrueso:agfino:edad:cenizas                               NA
# cemento:plastificante:aggrueso:agfino:edad:cenizas                      NA
# escoria:plastificante:aggrueso:agfino:edad:cenizas                      NA
# agua:plastificante:aggrueso:agfino:edad:cenizas                         NA
# cemento:escoria:agua:plastificante:aggrueso:agfino:edad                 NA
# cemento:escoria:agua:plastificante:aggrueso:agfino:cenizas       2.804e-11
# cemento:escoria:agua:plastificante:aggrueso:edad:cenizas                NA
# cemento:escoria:agua:plastificante:agfino:edad:cenizas                  NA
# cemento:escoria:agua:aggrueso:agfino:edad:cenizas                       NA
# cemento:escoria:plastificante:aggrueso:agfino:edad:cenizas              NA
# cemento:agua:plastificante:aggrueso:agfino:edad:cenizas                 NA
# escoria:agua:plastificante:aggrueso:agfino:edad:cenizas                 NA
# cemento:escoria:agua:plastificante:aggrueso:agfino:edad:cenizas         NA
#                                                                 t value
# (Intercept)                                                      -2.384
# cemento                                                           1.674
# escoria                                                           1.812
# agua                                                              2.449
# plastificante                                                    -0.940
# aggrueso                                                          2.256
# agfino                                                            2.322
# edad                                                             -0.093
# cenizas                                                           0.866
# cemento:escoria                                                  -0.985
# cemento:agua                                                     -1.730
# escoria:agua                                                     -1.795
# cemento:plastificante                                             0.908
# escoria:plastificante                                             0.933
# agua:plastificante                                                0.982
# cemento:aggrueso                                                 -1.496
# escoria:aggrueso                                                 -1.783
# agua:aggrueso                                                    -2.315
# plastificante:aggrueso                                            0.908
# cemento:agfino                                                   -1.406
# escoria:agfino                                                   -1.684
# agua:agfino                                                      -2.366
# plastificante:agfino                                              0.950
# aggrueso:agfino                                                  -2.186
# cemento:edad                                                      0.742
# escoria:edad                                                     -1.371
# agua:edad                                                         0.014
# plastificante:edad                                                0.946
# aggrueso:edad                                                     0.116
# agfino:edad                                                      -0.038
# cemento:cenizas                                                  -0.840
# escoria:cenizas                                                  -0.679
# agua:cenizas                                                     -0.246
# plastificante:cenizas                                             0.950
# aggrueso:cenizas                                                 -0.742
# agfino:cenizas                                                   -0.848
# edad:cenizas                                                     -0.850
# cemento:escoria:agua                                              0.932
# cemento:escoria:plastificante                                    -0.911
# cemento:agua:plastificante                                       -0.914
# escoria:agua:plastificante                                       -0.865
# cemento:escoria:aggrueso                                          0.995
# cemento:agua:aggrueso                                             1.554
# escoria:agua:aggrueso                                             1.765
# cemento:plastificante:aggrueso                                   -0.880
# escoria:plastificante:aggrueso                                   -0.262
# agua:plastificante:aggrueso                                      -0.935
# cemento:escoria:agfino                                            0.834
# cemento:agua:agfino                                               1.435
# escoria:agua:agfino                                               1.656
# cemento:plastificante:agfino                                     -0.919
# escoria:plastificante:agfino                                      0.064
# agua:plastificante:agfino                                        -0.997
# cemento:aggrueso:agfino                                           1.206
# escoria:aggrueso:agfino                                           1.655
# agua:aggrueso:agfino                                              2.227
# plastificante:aggrueso:agfino                                    -0.907
# cemento:escoria:edad                                              1.004
# cemento:agua:edad                                                -0.659
# escoria:agua:edad                                                 1.346
# cemento:plastificante:edad                                       -0.912
# escoria:plastificante:edad                                       -0.952
# agua:plastificante:edad                                          -0.989
# cemento:aggrueso:edad                                            -0.796
# escoria:aggrueso:edad                                             1.373
# agua:aggrueso:edad                                               -0.042
# plastificante:aggrueso:edad                                      -0.914
# cemento:agfino:edad                                              -0.659
# escoria:agfino:edad                                               1.307
# agua:agfino:edad                                                  0.099
# plastificante:agfino:edad                                        -0.957
# aggrueso:agfino:edad                                             -0.013
# cemento:escoria:cenizas                                           0.626
# cemento:agua:cenizas                                              0.751
# escoria:agua:cenizas                                              0.761
# cemento:plastificante:cenizas                                    -0.836
# escoria:plastificante:cenizas                                     0.940
# agua:plastificante:cenizas                                       -1.129
# cemento:aggrueso:cenizas                                          0.808
# escoria:aggrueso:cenizas                                          0.347
# agua:aggrueso:cenizas                                            -0.267
# plastificante:aggrueso:cenizas                                   -0.763
# cemento:agfino:cenizas                                            0.887
# escoria:agfino:cenizas                                            0.783
# agua:agfino:cenizas                                              -0.081
# plastificante:agfino:cenizas                                     -1.096
# aggrueso:agfino:cenizas                                           0.524
# cemento:edad:cenizas                                              0.849
# escoria:edad:cenizas                                              0.673
# agua:edad:cenizas                                                 0.225
# plastificante:edad:cenizas                                       -0.974
# aggrueso:edad:cenizas                                             0.722
# agfino:edad:cenizas                                               0.834
# cemento:escoria:agua:plastificante                                0.868
# cemento:escoria:agua:aggrueso                                    -0.942
# cemento:escoria:plastificante:aggrueso                            0.895
# cemento:agua:plastificante:aggrueso                               0.876
# escoria:agua:plastificante:aggrueso                               0.207
# cemento:escoria:agua:agfino                                      -0.772
# cemento:escoria:plastificante:agfino                              1.135
# cemento:agua:plastificante:agfino                                 0.928
# escoria:agua:plastificante:agfino                                -0.444
# cemento:escoria:aggrueso:agfino                                  -0.845
# cemento:agua:aggrueso:agfino                                     -1.240
# escoria:agua:aggrueso:agfino                                     -1.626
# cemento:plastificante:aggrueso:agfino                             0.884
# escoria:plastificante:aggrueso:agfino                            -0.731
# agua:plastificante:aggrueso:agfino                                0.934
# cemento:escoria:agua:edad                                        -0.976
# cemento:escoria:plastificante:edad                                0.917
# cemento:agua:plastificante:edad                                   0.917
# escoria:agua:plastificante:edad                                   0.886
# cemento:escoria:aggrueso:edad                                    -1.013
# cemento:agua:aggrueso:edad                                        0.718
# escoria:agua:aggrueso:edad                                       -1.347
# cemento:plastificante:aggrueso:edad                               0.883
# escoria:plastificante:aggrueso:edad                               0.330
# agua:plastificante:aggrueso:edad                                  0.942
# cemento:escoria:agfino:edad                                      -0.899
# cemento:agua:agfino:edad                                          0.597
# escoria:agua:agfino:edad                                         -1.277
# cemento:plastificante:agfino:edad                                 0.923
# escoria:plastificante:agfino:edad                                -0.017
# agua:plastificante:agfino:edad                                    1.005
# cemento:aggrueso:agfino:edad                                      0.749
# escoria:aggrueso:agfino:edad                                     -1.306
# ...
# agua:plastificante:aggrueso                                       0.3502
# cemento:escoria:agfino                                            0.4049
# cemento:agua:agfino                                               0.1519
# escoria:agua:agfino                                               0.0984 .
# cemento:plastificante:agfino                                      0.3584
# escoria:plastificante:agfino                                      0.9490
# agua:plastificante:agfino                                         0.3192
# cemento:aggrueso:agfino                                           0.2284
# escoria:aggrueso:agfino                                           0.0987 .
# agua:aggrueso:agfino                                              0.0264 *
# plastificante:aggrueso:agfino                                     0.3647
# cemento:escoria:edad                                              0.3159
# cemento:agua:edad                                                 0.5105
# escoria:agua:edad                                                 0.1790
# cemento:plastificante:edad                                        0.3625
# escoria:plastificante:edad                                        0.3418
# agua:plastificante:edad                                           0.3234
# cemento:aggrueso:edad                                             0.4263
# escoria:aggrueso:edad                                             0.1704
# agua:aggrueso:edad                                                0.9664
# plastificante:aggrueso:edad                                       0.3609
# cemento:agfino:edad                                               0.5099
# escoria:agfino:edad                                               0.1918
# agua:agfino:edad                                                  0.9215
# plastificante:agfino:edad                                         0.3390
# aggrueso:agfino:edad                                              0.9893
# cemento:escoria:cenizas                                           0.5314
# cemento:agua:cenizas                                              0.4529
# escoria:agua:cenizas                                              0.4473
# cemento:plastificante:cenizas                                     0.4037
# escoria:plastificante:cenizas                                     0.3477
# agua:plastificante:cenizas                                        0.2596
# cemento:aggrueso:cenizas                                          0.4196
# escoria:aggrueso:cenizas                                          0.7288
# agua:aggrueso:cenizas                                             0.7897
# plastificante:aggrueso:cenizas                                    0.4458
# cemento:agfino:cenizas                                            0.3754
# escoria:agfino:cenizas                                            0.4338
# agua:agfino:cenizas                                               0.9355
# plastificante:agfino:cenizas                                      0.2738
# aggrueso:agfino:cenizas                                           0.6004
# cemento:edad:cenizas                                              0.3960
# escoria:edad:cenizas                                              0.5012
# agua:edad:cenizas                                                 0.8222
# plastificante:edad:cenizas                                        0.3304
# aggrueso:edad:cenizas                                             0.4709
# agfino:edad:cenizas                                               0.4049
# cemento:escoria:agua:plastificante                                0.3857
# cemento:escoria:agua:aggrueso                                     0.3469
# cemento:escoria:plastificante:aggrueso                            0.3714
# cemento:agua:plastificante:aggrueso                               0.3813
# escoria:agua:plastificante:aggrueso                               0.8358
# cemento:escoria:agua:agfino                                       0.4406
# cemento:escoria:plastificante:agfino                              0.2570
# cemento:agua:plastificante:agfino                                 0.3539
# escoria:agua:plastificante:agfino                                 0.6570
# cemento:escoria:aggrueso:agfino                                   0.3984
# cemento:agua:aggrueso:agfino                                      0.2156
# escoria:agua:aggrueso:agfino                                      0.1047
# cemento:plastificante:aggrueso:agfino                             0.3773
# escoria:plastificante:aggrueso:agfino                             0.4654
# agua:plastificante:aggrueso:agfino                                0.3506
# cemento:escoria:agua:edad                                         0.3295
# cemento:escoria:plastificante:edad                                0.3594
# cemento:agua:plastificante:edad                                   0.3594
# escoria:agua:plastificante:edad                                   0.3759
# cemento:escoria:aggrueso:edad                                     0.3116
# cemento:agua:aggrueso:edad                                        0.4733
# escoria:agua:aggrueso:edad                                        0.1787
# cemento:plastificante:aggrueso:edad                               0.3777
# escoria:plastificante:aggrueso:edad                               0.7416
# agua:plastificante:aggrueso:edad                                  0.3467
# cemento:escoria:agfino:edad                                       0.3692
# cemento:agua:agfino:edad                                          0.5507
# escoria:agua:agfino:edad                                          0.2023
# cemento:plastificante:agfino:edad                                 0.3565
# escoria:plastificante:agfino:edad                                 0.9861
# agua:plastificante:agfino:edad                                    0.3152
# cemento:aggrueso:agfino:edad                                      0.4544
# escoria:aggrueso:agfino:edad                                      0.1923
# agua:aggrueso:agfino:edad                                         0.9650
# plastificante:aggrueso:agfino:edad                                0.3611
# cemento:escoria:agua:cenizas                                      0.6404
# cemento:escoria:plastificante:cenizas                             0.4069
# cemento:agua:plastificante:cenizas                                0.4683
# escoria:agua:plastificante:cenizas                                0.2614
# cemento:escoria:aggrueso:cenizas                                  0.6245
# cemento:agua:aggrueso:cenizas                                     0.5904
# escoria:agua:aggrueso:cenizas                                     0.6247
# cemento:plastificante:aggrueso:cenizas                            0.4111
# escoria:plastificante:aggrueso:cenizas                            0.4096
# agua:plastificante:aggrueso:cenizas                               0.4081
# cemento:escoria:agfino:cenizas                                    0.9818
# cemento:agua:agfino:cenizas                                       0.4243
# escoria:agua:agfino:cenizas                                       0.6453
# cemento:plastificante:agfino:cenizas                              0.5600
# escoria:plastificante:agfino:cenizas                              0.6983
# agua:plastificante:agfino:cenizas                                 0.7587
# cemento:aggrueso:agfino:cenizas                                   0.3928
# escoria:aggrueso:agfino:cenizas                                   0.9103
# agua:aggrueso:agfino:cenizas                                      0.6747
# plastificante:aggrueso:agfino:cenizas                             0.5697
# cemento:escoria:edad:cenizas                                      0.5361
# cemento:agua:edad:cenizas                                         0.4420
# escoria:agua:edad:cenizas                                         0.4515
# cemento:plastificante:edad:cenizas                                0.3754
# escoria:plastificante:edad:cenizas                                0.3461
# agua:plastificante:edad:cenizas                                   0.2434
# cemento:aggrueso:edad:cenizas                                     0.4074
# escoria:aggrueso:edad:cenizas                                     0.7357
# agua:aggrueso:edad:cenizas                                        0.7784
# plastificante:aggrueso:edad:cenizas                               0.4359
# cemento:agfino:edad:cenizas                                       0.3627
# escoria:agfino:edad:cenizas                                       0.4451
# agua:agfino:edad:cenizas                                          0.9264
# plastificante:agfino:edad:cenizas                                 0.2274
# aggrueso:agfino:edad:cenizas                                      0.6117
# cemento:escoria:agua:plastificante:aggrueso                       0.4151
# cemento:escoria:agua:plastificante:agfino                         0.3033
# cemento:escoria:agua:aggrueso:agfino                              0.4340
# cemento:escoria:plastificante:aggrueso:agfino                     0.6716
# cemento:agua:plastificante:aggrueso:agfino                        0.3795
# escoria:agua:plastificante:aggrueso:agfino                        0.4300
# cemento:escoria:agua:plastificante:edad                           0.3830
# cemento:escoria:agua:aggrueso:edad                                0.3256
# cemento:escoria:plastificante:aggrueso:edad                       0.3663
# cemento:agua:plastificante:aggrueso:edad                          0.3798
# escoria:agua:plastificante:aggrueso:edad                          0.7938
# cemento:escoria:agua:agfino:edad                                  0.3866
# cemento:escoria:plastificante:agfino:edad                         0.2468
# cemento:agua:plastificante:agfino:edad                            0.3521
# escoria:agua:plastificante:agfino:edad                            0.6786
# cemento:escoria:aggrueso:agfino:edad                              0.3642
# cemento:agua:aggrueso:agfino:edad                                 0.4919
# escoria:agua:aggrueso:agfino:edad                                 0.2033
# cemento:plastificante:aggrueso:agfino:edad                        0.3755
# escoria:plastificante:aggrueso:agfino:edad                        0.4742
# agua:plastificante:aggrueso:agfino:edad                           0.3465
# cemento:escoria:agua:plastificante:cenizas                        0.4200
# cemento:escoria:agua:aggrueso:cenizas                             0.6660
# cemento:escoria:plastificante:aggrueso:cenizas                    0.4950
# cemento:agua:plastificante:aggrueso:cenizas                       0.4089
# escoria:agua:plastificante:aggrueso:cenizas                       0.3327
# cemento:escoria:agua:agfino:cenizas                               0.8684
# cemento:escoria:plastificante:agfino:cenizas                      0.4068
# cemento:agua:plastificante:agfino:cenizas                         0.5605
# escoria:agua:plastificante:agfino:cenizas                         0.9778
# cemento:escoria:aggrueso:agfino:cenizas                           0.7421
# cemento:agua:aggrueso:agfino:cenizas                              0.3665
# escoria:agua:aggrueso:agfino:cenizas                              0.6716
# cemento:plastificante:aggrueso:agfino:cenizas                     0.6361
# escoria:plastificante:aggrueso:agfino:cenizas                     0.9427
# agua:plastificante:aggrueso:agfino:cenizas                        0.5515
# cemento:escoria:agua:edad:cenizas                                 0.6471
# cemento:escoria:plastificante:edad:cenizas                        0.4003
# cemento:agua:plastificante:edad:cenizas                           0.4489
# escoria:agua:plastificante:edad:cenizas                           0.2565
# cemento:escoria:aggrueso:edad:cenizas                             0.6350
# cemento:agua:aggrueso:edad:cenizas                                0.5490
# escoria:agua:aggrueso:edad:cenizas                                0.6348
# cemento:plastificante:aggrueso:edad:cenizas                       0.4028
# escoria:plastificante:aggrueso:edad:cenizas                       0.4085
# agua:plastificante:aggrueso:edad:cenizas                          0.3974
# cemento:escoria:agfino:edad:cenizas                               0.9943
# cemento:agua:agfino:edad:cenizas                                  0.3976
# escoria:agua:agfino:edad:cenizas                                  0.6546
# cemento:plastificante:agfino:edad:cenizas                         0.5680
# escoria:plastificante:agfino:edad:cenizas                         0.6728
# agua:plastificante:agfino:edad:cenizas                            0.7761
# cemento:aggrueso:agfino:edad:cenizas                              0.3510
# escoria:aggrueso:agfino:edad:cenizas                              0.8861
# agua:aggrueso:agfino:edad:cenizas                                 0.6700
# plastificante:aggrueso:agfino:edad:cenizas                        0.5463
# cemento:escoria:agua:plastificante:aggrueso:agfino                0.3587
# cemento:escoria:agua:plastificante:aggrueso:edad                  0.4116
# cemento:escoria:agua:plastificante:agfino:edad                    0.2938
# cemento:escoria:agua:aggrueso:agfino:edad                         0.3821
# cemento:escoria:plastificante:aggrueso:agfino:edad                0.6850
# cemento:agua:plastificante:aggrueso:agfino:edad                   0.3779
# escoria:agua:plastificante:aggrueso:agfino:edad                   0.4384
# cemento:escoria:agua:plastificante:aggrueso:cenizas               0.9625
# cemento:escoria:agua:plastificante:agfino:cenizas                 0.9451
# cemento:escoria:agua:aggrueso:agfino:cenizas                      0.7342
# cemento:escoria:plastificante:aggrueso:agfino:cenizas             0.9949
# cemento:agua:plastificante:aggrueso:agfino:cenizas                0.8082
# escoria:agua:plastificante:aggrueso:agfino:cenizas                0.9340
# cemento:escoria:agua:plastificante:edad:cenizas                   0.4022
# cemento:escoria:agua:aggrueso:edad:cenizas                        0.6795
# cemento:escoria:plastificante:aggrueso:edad:cenizas               0.4838
# cemento:agua:plastificante:aggrueso:edad:cenizas                  0.4041
# escoria:agua:plastificante:aggrueso:edad:cenizas                  0.2995
# cemento:escoria:agua:agfino:edad:cenizas                          0.8576
# cemento:escoria:plastificante:agfino:edad:cenizas                 0.3190
# cemento:agua:plastificante:agfino:edad:cenizas                    0.5640
# escoria:agua:plastificante:agfino:edad:cenizas                        NA
# cemento:escoria:aggrueso:agfino:edad:cenizas                          NA
# cemento:agua:aggrueso:agfino:edad:cenizas                             NA
# escoria:agua:aggrueso:agfino:edad:cenizas                             NA
# cemento:plastificante:aggrueso:agfino:edad:cenizas                    NA
# escoria:plastificante:aggrueso:agfino:edad:cenizas                    NA
# agua:plastificante:aggrueso:agfino:edad:cenizas                       NA
# cemento:escoria:agua:plastificante:aggrueso:agfino:edad               NA
# cemento:escoria:agua:plastificante:aggrueso:agfino:cenizas        0.9947
# cemento:escoria:agua:plastificante:aggrueso:edad:cenizas              NA
# cemento:escoria:agua:plastificante:agfino:edad:cenizas                NA
# cemento:escoria:agua:aggrueso:agfino:edad:cenizas                     NA
# cemento:escoria:plastificante:aggrueso:agfino:edad:cenizas            NA
# cemento:agua:plastificante:aggrueso:agfino:edad:cenizas               NA
# escoria:agua:plastificante:aggrueso:agfino:edad:cenizas               NA
# cemento:escoria:agua:plastificante:aggrueso:agfino:edad:cenizas       NA
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 6.8 on 480 degrees of freedom
# Multiple R-squared:  0.8955,	Adjusted R-squared:  0.8433
# F-statistic: 17.15 on 240 and 480 DF,  p-value: < 2.2e-16

# %%
length(lm_model$coefficients)
# Out:
# [1] 256

# %%
lm_yp_train<-predict(lm_model,concrete.train)
caret::postResample(pred=lm_yp_train, obs=concrete.train$resistencia)


lm_yp_test<-predict(lm_model,concrete.test)
caret::postResample(pred=lm_yp_test, obs=concrete.test$resistencia)
# Out:
# Warning message in predict.lm(lm_model, concrete.train):
# “prediction from a rank-deficient fit may be misleading”
#      RMSE  Rsquared       MAE
# 5.5481743 0.8955419 4.2784849
# Warning message in predict.lm(lm_model, concrete.test):
# “prediction from a rank-deficient fit may be misleading”
#       RMSE   Rsquared        MAE
# 11.6072400  0.6109302  7.5959611

# %% [markdown]
# **Regularización**

# %% [markdown]
# En este caso tenemos variables que provienen de diferentes unidades y tienen rangos muy diferentes de valores, por lo tanto para hacer los coeficientes comparables entre si, deberíamos estandarizarlos.
#
# El resultado consiste en dejar nuestros datos con media 0 y varianza 1:
# \\[
# X_n=\frac{X-\mu}{\sigma}
# \\]
#
# esto lo realiza por si solo el paquete glmnet o glmnetutils

# %%
cv<-glmnetUtils::cv.glmnet(formula=resistencia~cemento*escoria*cenizas*agua*plastificante*aggrueso*agfino*edad,
                            data=concrete.train,
                            alpha=1,
                            nfold= 10,
                            type.measure="mse",
                            standardize = T)


ggplot(data.frame(lambda=cv$lambda, cross_validated_mean_error=cv$cvm),
                   aes(x=lambda,y=cross_validated_mean_error))+geom_line()

paste0("El valor lambda con el menor error es:",cv$lambda.min)
paste0("El valor lambda más alto que se encuentra a una distancia 1sd es:",cv$lambda.1se)
paste0("El R^2 estimado es", 
       cv$glmnet.fit$dev.ratio[which(cv$glmnet.fit$lambda == cv$lambda.1se)]) 



ggplot(data.frame(lambda=cv$lambda,r2=cv$glmnet.fit$dev.ratio),
       aes(x=lambda,y=r2))+geom_line()+xlim(0,1)
# Out:
# [1] "El valor lambda con el menor error es:0.0139192430950643"
# [1] "El valor lambda más alto que se encuentra a una distancia 1sd es:0.524050567320565"
# [1] "El R^2 estimado es0.739486340528671"
# Warning message:
# “Removed 26 row(s) containing missing values (geom_path).”
# plot without title
# plot without title

# %%
reg_yp_train <- predict(cv,
                     concrete.train, 
                     s=cv$lambda.min)

caret::postResample(reg_yp_train,concrete.train$resistencia)
# Out:
#      RMSE  Rsquared       MAE
# 7.6877509 0.7995517 6.0515333

# %%
reg_yp_test <- predict(cv,
                     concrete.test, 
                     s=cv$lambda.min)
caret::postResample(reg_yp_test,concrete.test$resistencia)
# Out:
#      RMSE  Rsquared       MAE
# 8.3611229 0.7084761 6.5886842

# %% [markdown]
# \\[
# MSE = {1 \over n} \sum_{i=0}^n{(y_i-y_i')^2}
# \\]
# \\[
# R^2=1-\frac{\sum_i (y_i-y_i')^2}{\sum_i (y_i-\bar{y})^2}
# \\]

# %%
residual_test <- concrete.test$resistencia-reg_yp_test
plot(concrete.test$resistencia,residual_test)
qqnorm(residual_test)
qqline(residual_test,col="orange")
# Out:
# plot without title
# Plot with title “Normal Q-Q Plot”

# %%
data.frame(real=concrete.test$resistencia,
                       lm=lm_yp_test,
                       reg=reg_yp_test[,1]) %>% 
   mutate(res_lm=real-lm) %>% 
   mutate(res_reg=real-reg) -> total_pred
head(total_pred)
# Out:
#    real  lm        reg      res_lm     res_reg
# 4  41.05  43.83884 47.33107  -2.788835  -6.281065
# 5  44.30 118.97736 81.84714 -74.677356 -37.547142
# 6  47.03  48.67013 32.86738  -1.640131  14.162622
# 9  45.85  47.48403 27.75292  -1.634026  18.097078
# 11 38.07  36.78929 32.61979   1.280713   5.450207
# 14 42.33  46.07607 31.57650  -3.746072  10.753497

# %%
total_pred %>% ggplot(aes(x=real))+
  geom_point(aes(y=res_reg,color="Reg"),alpha=0.5)+
  geom_point(aes(y=res_lm,color="Lm"),alpha=0.5)
# Out:
# plot without title

# %%
library(reshape2)

total_pred %>% select(res_lm,res_reg) %>% melt() %>% 
  ggplot(aes(x=value,color=variable))+geom_histogram(position='dodge', aes(fill=variable))
# Out:
# No id variables; using all as measure variables
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %% [markdown]
# **Si utilizamos lambda.1se como valor de lambda** el R² y el MSE empeoran ligeramente, pero siguen siendo mejores que la regresión lineal.

# %%
reg_yp_train <- predict(cv,
                     concrete.train, 
                     s=cv$lambda.1se)
caret::postResample(reg_yp_train,concrete.train$resistencia)

reg_yp_test <- predict(cv,
                     concrete.test, 
                     s=cv$lambda.1se)
caret::postResample(reg_yp_test,concrete.test$resistencia)

data.frame(real=concrete.test$resistencia,
                       lm=lm_yp_test,
                       reg=reg_yp_test[,1]) %>% 
   mutate(res_lm=real-lm) %>% 
   mutate(res_reg=real-reg) -> total_pred

total_pred %>% select(res_lm,res_reg) %>% melt() %>% 
  ggplot(aes(x=value,color=variable))+geom_density()

# %%
#¿Tiene sesgo nuestro modelo?
colMeans(total_pred[,c("res_lm","res_reg")])
